# %%
from glob import glob
from os.path import basename
import pandas as pd
import seaborn as sns; sns.set()
import numpy as np
import re

# %%
# %matplotlib inline

# %%
def get_dssp(fn):
    f = open(DATA_PATH+"/dssp/"+fn)
    _ = f.readline()
    dssp = f.readline()
    f.close()
    return [m.group(0) for m in re.finditer(r"(.)\1*", dssp)]

# %%
def get_stride(fn):
    f = open(DATA_PATH+"/stride/"+fn)
    _ = f.readline()
    stride = f.readline()
    f.close()
    return [m.group(0) for m in re.finditer(r"(.)\1*", stride)]

# %%
def get_kaksi(fn):
    f = open(DATA_PATH+"/kaksi/"+fn)
    _ = f.readline()
    kaksi = f.readline()
    f.close()
    return [m.group(0) for m in re.finditer(r"(.)\1*", kaksi)]

# %%
def get_pross(fn):
    f = open(DATA_PATH+"/pross/"+fn)
    _ = f.readline()
    pross = f.readline()
    f.close()
    return [m.group(0) for m in re.finditer(r"(.)\1*", pross)]

# %%
DATA_PATH="/home/jgcarvalho/zeca-analyse-pos_quali/Top8000-best_hom50_pdb_chain/cba_times_mcc/rose_special_charged/run_10000"
segs_dssp = []
segs_stride = []
segs_kaksi = []
segs_pross = []
segs = []
for fn in glob(DATA_PATH+"/seq/*"):
    f = basename(fn)
    dssp = get_dssp(f)
    stride = get_stride(f)
    kaksi = get_kaksi(f)
    pross = get_pross(f)
    segs += [{"Method":"DSSP","File":f,"Segment":x,"Length":len(x)} for x in dssp]
#     segs += segs_dssp
    segs += [{"Method":"STRIDE","File":f,"Segment":x,"Length":len(x)} for x in stride]
#     segs += segs_stride
    segs += [{"Method":"KAKSI","File":f,"Segment":x,"Length":len(x)} for x in kaksi]
#     segs += segs_kaksi
    segs += [{"Method":"PROSS","File":f,"Segment":x,"Length":len(x)} for x in pross]
#     segs += segs_pross
pd_dssp = pd.DataFrame(segs_dssp)
pd_stride = pd.DataFrame(segs_stride)
pd_kaksi = pd.DataFrame(segs_kaksi)
pd_pross = pd.DataFrame(segs_pross)
pd_segs = pd.DataFrame(segs)

# %%
fig = sns.boxplot(x="Method", y="Length", data=pd_segs[pd_segs['Segment'].str.contains('H')], showfliers=False)
fig.set(xlabel='Método de atribuição', ylabel='Número de resíduos',title="Distribuição do comprimento de hélices")
fig.figure.savefig("../figures/distribuicao_comprimento_helices.pdf")

# %%
fig = sns.boxplot(x="Method", y="Length", data=pd_segs[pd_segs['Segment'].str.contains('E')], showfliers=False)
fig.set(xlabel='Método de atribuição', ylabel='Número de resíduos',title="Distribuição do comprimento de fitas")
fig.figure.savefig("../figures/distribuicao_comprimento_fitas.pdf")

# %%
sns.boxplot(x="Method", y="Length", data=pd_segs[(pd_segs['Segment'].str.contains('C')) & (pd_segs['Method']!="KAKSI")])

# %%
pd_segs[pd_segs['Segment'].str.contains('C')].sort_values(by="Length", ascending=False)
# Out:
#           File  Length  Method  \
# 753554   2p4eP     546   KAKSI
# 789573   3jzyA     386   KAKSI
# 995619   2j8kA     168   KAKSI
# 995610   2j8kA     164    DSSP
# 995623   2j8kA     163   PROSS
# 608709   1h6wA     163   KAKSI
# 995615   2j8kA     163  STRIDE
# 889296   3evyB     148   KAKSI
# 702884   2wy3A     144   KAKSI
# 781097   1me8A     137   KAKSI
# 549112   1b6aA     132   KAKSI
# 247703   2xi9B     127   KAKSI
# 772325   2wanA     115   KAKSI
# 1008456  2wh7A     115   KAKSI
# 756187   3qaoA     111   KAKSI
# 28724    3o83B     109   KAKSI
# 127078   1ocyA     108   KAKSI
# 766703   3aiiA      96   KAKSI
# 686206   3eggD      95   KAKSI
# 1008435  2wh7A      94    DSSP
# 151754   1skzA      94   KAKSI
# 532440   2y81B      94   KAKSI
# 967874   2o0mA      94   KAKSI
# 1008446  2wh7A      94  STRIDE
# 441423   2qtzA      89   KAKSI
# 626838   2h9bA      89   KAKSI
# 887783   3onpA      89   KAKSI
# 1007525  3crmA      89   KAKSI
# 840983   1c4oA      88   KAKSI
# 890413   1y80A      88   KAKSI
# ...        ...     ...     ...
# 481887   2rciA       1   KAKSI
# 481883   2rciA       1   KAKSI
# 228818   1uuqA       1   PROSS
# 481879   2rciA       1   KAKSI
# 756835   2a4vA       1   KAKSI
# 228756   1uuqA       1   KAKSI
# 228752   1uuqA       1   KAKSI
# 228580   1wnaA       1   KAKSI
# 756729   2xm4A       1  STRIDE
# 921430   2dbyA       1  STRIDE
# 228598   1wnaA       1   KAKSI
# 756715   2xm4A       1    DSSP
# 228620   1wnaA       1   PROSS
# 482043   2v7kA       1   KAKSI
# 228631   1uuqA       1    DSSP
# 482041   2v7kA       1   KAKSI
# 921405   2dbyA       1    DSSP
# 482037   2v7kA       1   KAKSI
# 921392   2dbyA       1    DSSP
# 228748   1uuqA       1   KAKSI
# 228649   1uuqA       1    DSSP
# 482031   2v7kA       1   KAKSI
# 482029   2v7kA       1   KAKSI
# 921380   2dbyA       1    DSSP
# 756750   2xm4A       1   PROSS
# 921364   2dbyA       1    DSSP
# 228690   1uuqA       1  STRIDE
# 228708   1uuqA       1  STRIDE
# 228734   1uuqA       1  STRIDE
# 646834   3mk1A       1  STRIDE
#
#                                                    Segment
# 753554   CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC...
# 789573   CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC...
# 995619   CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC...
# 995610   CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC...
# 995623   CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC...
# 608709   CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC...
# 995615   CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC...
# 889296   CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC...
# 702884   CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC...
# 781097   CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC...
# 549112   CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC...
# 247703   CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC...
# 772325   CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC...
# 1008456  CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC...
# 756187   CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC...
# 28724    CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC...
# 127078   CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC...
# 766703   CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC...
# 686206   CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC...
# 1008435  CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC...
# 151754   CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC...
# 532440   CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC...
# 967874   CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC...
# 1008446  CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC...
# 441423   CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC...
# 626838   CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC...
# 887783   CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC...
# 1007525  CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC...
# 840983   CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC...
# 890413   CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC...
# ...                                                    ...
# 481887                                                   C
# 481883                                                   C
# 228818                                                   C
# 481879                                                   C
# 756835                                                   C
# 228756                                                   C
# 228752                                                   C
# 228580                                                   C
# 756729                                                   C
# 921430                                                   C
# 228598                                                   C
# 756715                                                   C
# 228620                                                   C
# 482043                                                   C
# 228631                                                   C
# 482041                                                   C
# 921405                                                   C
# 482037                                                   C
# 921392                                                   C
# 228748                                                   C
# 228649                                                   C
# 482031                                                   C
# 482029                                                   C
# 921380                                                   C
# 756750                                                   C
# 921364                                                   C
# 228690                                                   C
# 228708                                                   C
# 228734                                                   C
# 646834                                                   C
#
# [521335 rows x 4 columns]

# %%
pd_segs[pd_segs['Segment'].str.contains('E')].sort_values(by="Length", ascending=False)
# Out:
#           File  Length  Method                       Segment
# 930498   1czfA      28    DSSP  EEEEEEEEEEEEEEEEEEEEEEEEEEEE
# 508726   1uu4A      28  STRIDE  EEEEEEEEEEEEEEEEEEEEEEEEEEEE
# 863986   1h4gA      27    DSSP   EEEEEEEEEEEEEEEEEEEEEEEEEEE
# 864016   1h4gA      27  STRIDE   EEEEEEEEEEEEEEEEEEEEEEEEEEE
# 976617   2x55A      26  STRIDE    EEEEEEEEEEEEEEEEEEEEEEEEEE
# 976585   2x55A      26    DSSP    EEEEEEEEEEEEEEEEEEEEEEEEEE
# 1021210  1oa2C      25  STRIDE     EEEEEEEEEEEEEEEEEEEEEEEEE
# 251070   3isrA      25   KAKSI     EEEEEEEEEEEEEEEEEEEEEEEEE
# 438173   3g5kD      25  STRIDE     EEEEEEEEEEEEEEEEEEEEEEEEE
# 882402   1jpeA      25  STRIDE     EEEEEEEEEEEEEEEEEEEEEEEEE
# 208113   3e8tA      24    DSSP      EEEEEEEEEEEEEEEEEEEEEEEE
# 976598   2x55A      24    DSSP      EEEEEEEEEEEEEEEEEEEEEEEE
# 864003   1h4gA      24  STRIDE      EEEEEEEEEEEEEEEEEEEEEEEE
# 463800   2in8A      24   KAKSI      EEEEEEEEEEEEEEEEEEEEEEEE
# 930496   1czfA      24    DSSP      EEEEEEEEEEEEEEEEEEEEEEEE
# 208145   3e8tA      24  STRIDE      EEEEEEEEEEEEEEEEEEEEEEEE
# 463810   2in8A      24   KAKSI      EEEEEEEEEEEEEEEEEEEEEEEE
# 1021159  1oa2C      24    DSSP      EEEEEEEEEEEEEEEEEEEEEEEE
# 976579   2x55A      24    DSSP      EEEEEEEEEEEEEEEEEEEEEEEE
# 863972   1h4gA      24    DSSP      EEEEEEEEEEEEEEEEEEEEEEEE
# 976611   2x55A      24  STRIDE      EEEEEEEEEEEEEEEEEEEEEEEE
# 645681   1ftrA      23   KAKSI       EEEEEEEEEEEEEEEEEEEEEEE
# 442971   2dfbA      23  STRIDE       EEEEEEEEEEEEEEEEEEEEEEE
# 545944   2wnvE      23   KAKSI       EEEEEEEEEEEEEEEEEEEEEEE
# 171646   2htaA      23   KAKSI       EEEEEEEEEEEEEEEEEEEEEEE
# 539931   3hwuA      23    DSSP       EEEEEEEEEEEEEEEEEEEEEEE
# 539963   3hwuA      23  STRIDE       EEEEEEEEEEEEEEEEEEEEEEE
# 959850   3iibA      23  STRIDE       EEEEEEEEEEEEEEEEEEEEEEE
# 959825   3iibA      23  STRIDE       EEEEEEEEEEEEEEEEEEEEEEE
# 959751   3iibA      23    DSSP       EEEEEEEEEEEEEEEEEEEEEEE
# ...        ...     ...     ...                           ...
# 693562   3mswA       1    DSSP                             E
# 693570   3mswA       1  STRIDE                             E
# 693574   3mswA       1  STRIDE                             E
# 291368   3lm3A       1    DSSP                             E
# 867052   3pplB       1  STRIDE                             E
# 456880   3nqnB       1    DSSP                             E
# 478257   2gwgB       1    DSSP                             E
# 236720   3mhzA       1    DSSP                             E
# 188483   3g9kL       1    DSSP                             E
# 497922   3kyaA       1    DSSP                             E
# 212650   2r2zA       1  STRIDE                             E
# 777051   3lk7A       1  STRIDE                             E
# 777030   3lk7A       1  STRIDE                             E
# 212626   2r2zA       1    DSSP                             E
# 634276   3o0lA       1    DSSP                             E
# 634290   3o0lA       1    DSSP                             E
# 607429   2eqaA       1   KAKSI                             E
# 867642   1zwyC       1    DSSP                             E
# 776998   3lk7A       1    DSSP                             E
# 291132   3nwcB       1  STRIDE                             E
# 776980   3lk7A       1    DSSP                             E
# 5922     3cqbB       1    DSSP                             E
# 236783   3mhzA       1    DSSP                             E
# 607316   2eqaA       1    DSSP                             E
# 776953   3lk7A       1    DSSP                             E
# 497778   3ha2A       1    DSSP                             E
# 977015   3m7aA       1    DSSP                             E
# 1011199  3hn7A       1    DSSP                             E
# 940377   1uwwA       1  STRIDE                             E
# 746266   3g5sA       1  STRIDE                             E
#
# [265876 rows x 4 columns]

# %%
pd_dssp[pd_dssp['Segment'].str.contains('H')]["Length"].hist(alpha=0.5)

# %%
pd_stride[pd_stride['Segment'].str.contains('H')]["Length"].hist(alpha=0.5)

# %%
pd_kaksi[pd_kaksi['Segment'].str.contains('H')]["Length"].hist(alpha=0.5)

# %%
pd_pross[pd_pross['Segment'].str.contains('H')]["Length"].hist(alpha=0.5)

# %%
pd_dssp[pd_dssp['Segment'].str.contains('H')]["Length"].hist(alpha=0.5, bins=1)
pd_stride[pd_stride['Segment'].str.contains('H')]["Length"].hist(alpha=0.5, bins=1)
pd_kaksi[pd_kaksi['Segment'].str.contains('H')]["Length"].hist(alpha=0.5, bins=1)
pd_pross[pd_pross['Segment'].str.contains('H')]["Length"].hist(alpha=0.5, bins=1)

# %%
pd_dssp[pd_dssp['Segment'].str.contains('H')].boxplot()
pd_stride[pd_stride['Segment'].str.contains('H')].boxplot()

# %%
pd_segs[pd_segs['Segment'].str.contains('H')].boxplot(by="Method")

# %%
sns.violinplot(x="Method", y="Length", data=pd_segs[pd_segs['Segment'].str.contains('H')])

# %%
pd_stride[pd_stride['Segment'].str.contains('H')].count()
# Out:
# File       63666
# Length     63666
# Method     63666
# Segment    63666
# dtype: int64

# %%
pd_kaksi[pd_kaksi['Segment'].str.contains('C')].count()
# Out:
# File       122311
# Length     122311
# Method     122311
# Segment    122311
# dtype: int64

# %%
pd_pross[pd_pross['Segment'].str.contains('H')].count()
# Out:
# File       47346
# Length     47346
# Method     47346
# Segment    47346
# dtype: int64
